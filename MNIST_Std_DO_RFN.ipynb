# %% [markdown]
# ## IDS576 - Team 3
# #### 1) Training MNIST Models:
# - Standard
# - Dropout
# - Random Feature Nullification (RFN)
#
# #### 2) Evaluate with FSGM Adversary Samples

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import SubsetRandomSampler, TensorDataset, DataLoader
import torch.nn.functional as F
from torchvision import datasets, models, transforms
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %config IPCompleter.greedy = True
random_seed = 0
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# #### Import MNIST dataset and prepare for training

# %%
train_transform = transforms.Compose([
        transforms.ToTensor()])
    
val_transform = transforms.Compose([
        transforms.ToTensor()])

# %%
# Download train and test data
data_path = '~/IDS576/data'
trainset = datasets.MNIST(root=data_path, train=True, download=True, transform=train_transform)
valset = datasets.MNIST(root=data_path, train=True, download=True, transform=val_transform)
testset = datasets.MNIST(root=data_path, train=False, download=True, transform=val_transform)

# %%
# Split train data in to train and validation data using torch dataset and utils.data modules

val_size = .2
n_train = len(trainset)

# get train set indices and split point based on val size
indices = list(range(n_train))
split = int(np.floor(val_size * n_train))

# shuffle trainset indices
np.random.seed(random_seed)
np.random.shuffle(indices)

# split train into train and val with shuffled indices at split point. 
train_idx, val_idx = indices[split:], indices[:split]

# Create train and val samplers based in split indices for use with DataLoader batch sampling
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)
full_train_sampler = SubsetRandomSampler(indices)

batch_size = 128 # per paper
n_trn = n_train*(1-val_size)
batches = n_trn/batch_size

# CUDA settings
num_workers = 0 # allows preload of next batch, but greater than zero isn't recommended for cuda ops
pin_memory = True

train_dl = DataLoader(
    trainset, batch_size=batch_size, sampler=train_sampler,
    num_workers=num_workers, pin_memory=pin_memory)

val_dl = DataLoader(
    valset, batch_size=batch_size, sampler=val_sampler,
    num_workers=num_workers, pin_memory=pin_memory)

full_train_dl = DataLoader(
    trainset, batch_size=batch_size, sampler=full_train_sampler,
    num_workers=num_workers, pin_memory=pin_memory)

test_dl = DataLoader(
    testset, batch_size=batch_size,
    num_workers=num_workers, pin_memory=pin_memory)

def single_dl(xy, batch_size=1):
    return DataLoader(xy, batch_size=batch_size, num_workers=1, pin_memory=pin_memory)

# %%
classes = trainset.classes
classdict = {label: name for label, name in enumerate(classes)}
print(classes)
# Out:
# ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four', '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

# %% [markdown]
# #### Train models on MNIST

# %%
def loss_batch(model, loss_func, xb, yb, opt=None):
    xb = xb.to(device)
    yb = yb.to(device)
    correct = 0
    output = model(xb)
    _, preds = torch.max(output, 1)
    correct = torch.sum(preds == yb)
    acc = correct.double()/len(yb)
    loss = loss_func(output, yb)
    if opt is not None:
        loss.backward()
        opt.step()
        opt.zero_grad()
    return loss.item(), len(xb), acc   

def fit(epochs, model, loss_func, opt, train_dl, val_dl):
    mod = n_trn/(batch_size*20)
    running_corrects = 0
    val_accs = []
    val_losses = []
    for epoch in range(epochs):
        since = time.time()
        model.train()
        #i=0
        print(f'Epoch {epoch+1}/{epochs}: [', end='')
        for i, (xb, yb) in enumerate(train_dl):
            if not i % mod:
                print('*', end='')
            loss_batch(model, loss_func, xb, yb, opt)
            #i+=1
        print(']', end='')
        model.eval()
        print(' Val Loss: ', end='')
        with torch.no_grad():
            losses, nums, acc = zip(*[loss_batch(model, loss_func, xb, yb) for xb, yb in val_dl])
        val_loss = np.sum(np.multiply(losses, nums)) / np.sum(nums)
        val_acc = np.sum(np.multiply(acc, nums)) / np.sum(nums)
        
        # Save history
        val_losses.append(val_loss)
        val_accs.append(val_acc)

        print(f'{val_loss:6.4f}, Val Acc: {val_acc:6.4f} ', end='')
        until = time.time()
        print(f'Elapsed (sec): {until-since:<5.1f}')
    return val_accs, val_losses

# %%
trainset[0][0].size()
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# #### Define models from paper appendix

# %%
class MNIST_Standard(nn.Module):
    
    def __init__(self):
        super(MNIST_Standard, self).__init__()
        self.fc1 = nn.Linear(1 * 28 * 28, 784)
        self.fc2 = nn.Linear(784, 784)
        self.fc3 = nn.Linear(784, 784)
        self.fc4 = nn.Linear(784, 10)
                             
    def forward(self, x):
        x = x.view(-1, 1 * 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
class MNIST_Dropout(nn.Module):
    
    def __init__(self):
        super(MNIST_Dropout, self).__init__()
        self.fc1 = nn.Linear(1 * 28 * 28, 784)
        self.fc2 = nn.Linear(784, 784)
        self.fc3 = nn.Linear(784, 784)
        self.fc4 = nn.Linear(784, 10)
        self.dropout = nn.Dropout(.5)
                             
    def forward(self, x):
        x = x.view(-1, 1 * 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
class MNIST_RFN(nn.Module):
    
    def __init__(self):
        super(MNIST_RFN, self).__init__()
        self.fc1 = nn.Linear(1 * 28 * 28, 784)
        self.fc2 = nn.Linear(784, 784)
        self.fc3 = nn.Linear(784, 784)
        self.fc4 = nn.Linear(784, 10)
        self.dropout = nn.Dropout(.25)
                             
    def forward(self, x):
        x = x.view(-1, 1 * 28 * 28)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        return x

# %%
import torch.nn as nn
import torch
import numpy as np

class RFN(nn.Module):
    '''Wrapper class that takes any nn.Module based model and adds an RFN layer prior to all other layers.'''
    
    
    def __init__(self, model, mu=.1, sigma=.05, rfn_flag=True):
        super(RFN, self).__init__()
        self.model = model
        self.mu = mu
        self.sigma = sigma
        self.rfn_flag = rfn_flag
        self.shape_vals = None

    def forward(self, x):
        if self.rfn_flag:
            x = self.random_masks(x) * x
            x = self.model(x)
        else:
            x = self.model(x)
        return x
    
    
    def random_masks(self, x):
        # Calculate shape values for x
        self.shape_vals = x.size(), x[0].size(), x[0].nelement()

        # Create ones array of size (batch,channel,horiz,vert)
        masks = np.ones(self.shape_vals[0])

        # Create random masks for each sample in the batch
        for mask in masks:
            zero_cnt = np.absolute(int(np.ceil((self.sigma * np.random.randn() + self.mu) * self.shape_vals[2])))
            zero_idx = np.random.choice(self.shape_vals[2], zero_cnt, replace=False)
            mask.reshape(self.shape_vals[2])[zero_idx] = 0
            mask.reshape(self.shape_vals[1])
        return torch.tensor(masks, dtype=torch.float, device=device)

# %% [markdown]
# #### Train Standard, Dropout, and RFN models at 25 epochs each on trainset eval in validation set

# %%
# Create dictionary to store training history for all models
models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]

history = {}
for model_name in models.keys():
    history[model_name] = {}
    for mu in rfn_mu_vals:
        history[model_name][mu] = {}

# %%
# Train Standard, Dropout, and RFN MNIST model using paper hyperparameters
# Train on train data, eval on validation data to determine epoch cutoff
# Here we use epochs = 25 as used in paper

models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]
epochs = 25

for model_name, model_instance in models.items():
    print()
    for mu in rfn_mu_vals:    
        # Set whether RFN will be used in training
        if mu == 0:
            rfn_flag = False
        else:
            rfn_flag = True
        
        # Standard and Dropout models don't need to be trained with RFN
        if model_name != 'RFN' and mu != 0:
            print(f'Skip {model_name} at mu={mu}')
            continue
            
        print(f'Training {model_name}: RFN={rfn_flag}, mu={mu}:')     
        model = model_instance
        model.to(device)
        rfn_wrapper = RFN(model, mu=mu, sigma=.05, rfn_flag=rfn_flag)
        rfn_wrapper.to(device)

        loss_func = nn.CrossEntropyLoss()
        opt = optim.SGD(model.parameters(), lr=0.1) # Opt and LR per paper
        
        # Save tuple of epoch val accuracy and val loss to history dict
        history[model_name][mu] = fit(epochs, rfn_wrapper, loss_func, opt, train_dl, val_dl)

        # Save model
        PATH = f'./models/MNIST_{model_name}_{mu}.pth'
        torch.save(model.state_dict(), PATH)
# Out:
# Training Standard: RFN=False, mu=0:
# Epoch 1/25: [*****] Val Loss: 0.3218, Val Acc: 0.9050 Elapsed (sec): 5.3
# Epoch 2/25: [*****] Val Loss: 0.2269, Val Acc: 0.9293 Elapsed (sec): 5.2
# Epoch 3/25: [*****] Val Loss: 0.1595, Val Acc: 0.9510 Elapsed (sec): 5.5
# Epoch 4/25: [*****] Val Loss: 0.1377, Val Acc: 0.9587 Elapsed (sec): 5.5
# Epoch 5/25: [*****] Val Loss: 0.1021, Val Acc: 0.9690 Elapsed (sec): 5.5
# Epoch 6/25: [*****] Val Loss: 0.0952, Val Acc: 0.9714 Elapsed (sec): 5.1
# Epoch 7/25: [*****] Val Loss: 0.0818, Val Acc: 0.9751 Elapsed (sec): 5.6
# Epoch 8/25: [*****] Val Loss: 0.0869, Val Acc: 0.9736 Elapsed (sec): 5.5
# Epoch 9/25: [*****] Val Loss: 0.0790, Val Acc: 0.9750 Elapsed (sec): 5.5
# Epoch 10/25: [*****] Val Loss: 0.0705, Val Acc: 0.9778 Elapsed (sec): 5.4
# Epoch 11/25: [*****] Val Loss: 0.0730, Val Acc: 0.9788 Elapsed (sec): 4.9
# Epoch 12/25: [*****] Val Loss: 0.0739, Val Acc: 0.9778 Elapsed (sec): 5.5
# Epoch 13/25: [*****] Val Loss: 0.0732, Val Acc: 0.9782 Elapsed (sec): 5.5
# Epoch 14/25: [*****] Val Loss: 0.0761, Val Acc: 0.9780 Elapsed (sec): 5.5
# Epoch 15/25: [*****] Val Loss: 0.0715, Val Acc: 0.9799 Elapsed (sec): 5.3
# Epoch 16/25: [*****] Val Loss: 0.0714, Val Acc: 0.9810 Elapsed (sec): 5.2
# Epoch 17/25: [*****] Val Loss: 0.0696, Val Acc: 0.9799 Elapsed (sec): 5.4
# Epoch 18/25: [*****] Val Loss: 0.0689, Val Acc: 0.9821 Elapsed (sec): 5.5
# Epoch 19/25: [*****] Val Loss: 0.0706, Val Acc: 0.9812 Elapsed (sec): 5.5
# Epoch 20/25: [*****] Val Loss: 0.0722, Val Acc: 0.9803 Elapsed (sec): 5.0
# Epoch 21/25: [*****] Val Loss: 0.0720, Val Acc: 0.9812 Elapsed (sec): 5.5
# Epoch 22/25: [*****] Val Loss: 0.0884, Val Acc: 0.9760 Elapsed (sec): 5.5
# Epoch 23/25: [*****] Val Loss: 0.0720, Val Acc: 0.9821 Elapsed (sec): 5.5
# Epoch 24/25: [*****] Val Loss: 0.0720, Val Acc: 0.9816 Elapsed (sec): 5.5
# Epoch 25/25: [*****] Val Loss: 0.0739, Val Acc: 0.9818 Elapsed (sec): 4.9
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
#
# Training Dropout: RFN=False, mu=0:
# Epoch 1/25: [*****] Val Loss: 0.3103, Val Acc: 0.9100 Elapsed (sec): 5.5
# Epoch 2/25: [*****] Val Loss: 0.2018, Val Acc: 0.9403 Elapsed (sec): 5.5
# Epoch 3/25: [*****] Val Loss: 0.1563, Val Acc: 0.9542 Elapsed (sec): 5.6
# Epoch 4/25: [*****] Val Loss: 0.1212, Val Acc: 0.9635 Elapsed (sec): 5.4
# Epoch 5/25: [*****] Val Loss: 0.1049, Val Acc: 0.9680 Elapsed (sec): 5.2
# Epoch 6/25: [*****] Val Loss: 0.0898, Val Acc: 0.9718 Elapsed (sec): 5.4
# Epoch 7/25: [*****] Val Loss: 0.0887, Val Acc: 0.9731 Elapsed (sec): 5.5
# Epoch 8/25: [*****] Val Loss: 0.0837, Val Acc: 0.9744 Elapsed (sec): 5.5
# Epoch 9/25: [*****] Val Loss: 0.0729, Val Acc: 0.9778 Elapsed (sec): 5.2
# Epoch 10/25: [*****] Val Loss: 0.0727, Val Acc: 0.9772 Elapsed (sec): 5.5
# Epoch 11/25: [*****] Val Loss: 0.0805, Val Acc: 0.9761 Elapsed (sec): 5.5
# Epoch 12/25: [*****] Val Loss: 0.0895, Val Acc: 0.9743 Elapsed (sec): 5.5
# Epoch 13/25: [*****] Val Loss: 0.0697, Val Acc: 0.9784 Elapsed (sec): 5.5
# Epoch 14/25: [*****] Val Loss: 0.0917, Val Acc: 0.9738 Elapsed (sec): 4.9
# Epoch 15/25: [*****] Val Loss: 0.0682, Val Acc: 0.9799 Elapsed (sec): 5.5
# Epoch 16/25: [*****] Val Loss: 0.0717, Val Acc: 0.9789 Elapsed (sec): 5.5
# Epoch 17/25: [*****] Val Loss: 0.0687, Val Acc: 0.9800 Elapsed (sec): 5.5
# Epoch 18/25: [*****] Val Loss: 0.0707, Val Acc: 0.9799 Elapsed (sec): 5.3
# Epoch 19/25: [*****] Val Loss: 0.0774, Val Acc: 0.9781 Elapsed (sec): 5.2
# Epoch 20/25: [*****] Val Loss: 0.0708, Val Acc: 0.9802 Elapsed (sec): 5.5
# Epoch 21/25: [*****] Val Loss: 0.0713, Val Acc: 0.9810 Elapsed (sec): 5.6
# Epoch 22/25: [*****] Val Loss: 0.0726, Val Acc: 0.9808 Elapsed (sec): 5.6
# Epoch 23/25: [*****] Val Loss: 0.0741, Val Acc: 0.9806 Elapsed (sec): 5.1
# Epoch 24/25: [*****] Val Loss: 0.0728, Val Acc: 0.9812 Elapsed (sec): 5.5
# Epoch 25/25: [*****] Val Loss: 0.0742, Val Acc: 0.9808 Elapsed (sec): 5.5
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
#
# Training RFN: RFN=False, mu=0:
# Epoch 1/25: [*****] Val Loss: 0.3135, Val Acc: 0.9076 Elapsed (sec): 5.5
# Epoch 2/25: [*****] Val Loss: 0.1981, Val Acc: 0.9420 Elapsed (sec): 5.5
# Epoch 3/25: [*****] Val Loss: 0.1650, Val Acc: 0.9515 Elapsed (sec): 5.0
# Epoch 4/25: [*****] Val Loss: 0.1252, Val Acc: 0.9616 Elapsed (sec): 5.5
# Epoch 5/25: [*****] Val Loss: 0.1059, Val Acc: 0.9676 Elapsed (sec): 5.5
# Epoch 6/25: [*****] Val Loss: 0.0922, Val Acc: 0.9712 Elapsed (sec): 5.5
# Epoch 7/25: [*****] Val Loss: 0.0859, Val Acc: 0.9737 Elapsed (sec): 5.3
# Epoch 8/25: [*****] Val Loss: 0.0786, Val Acc: 0.9752 Elapsed (sec): 5.1
# Epoch 9/25: [*****] Val Loss: 0.0726, Val Acc: 0.9771 Elapsed (sec): 5.5
# Epoch 10/25: [*****] Val Loss: 0.0724, Val Acc: 0.9774 Elapsed (sec): 5.5
# Epoch 11/25: [*****] Val Loss: 0.0750, Val Acc: 0.9769 Elapsed (sec): 5.5
# Epoch 12/25: [*****] Val Loss: 0.0760, Val Acc: 0.9755 Elapsed (sec): 5.1
# Epoch 13/25: [*****] Val Loss: 0.0683, Val Acc: 0.9787 Elapsed (sec): 5.5
# Epoch 14/25: [*****] Val Loss: 0.0700, Val Acc: 0.9782 Elapsed (sec): 5.4
# Epoch 15/25: [*****] Val Loss: 0.0745, Val Acc: 0.9779 Elapsed (sec): 5.5
# Epoch 16/25: [*****] Val Loss: 0.0735, Val Acc: 0.9789 Elapsed (sec): 5.5
# Epoch 17/25: [*****] Val Loss: 0.0730, Val Acc: 0.9786 Elapsed (sec): 4.9
# Epoch 18/25: [*****] Val Loss: 0.0680, Val Acc: 0.9805 Elapsed (sec): 5.5
# Epoch 19/25: [*****] Val Loss: 0.0706, Val Acc: 0.9801 Elapsed (sec): 5.5
# Epoch 20/25: [*****] Val Loss: 0.0708, Val Acc: 0.9811 Elapsed (sec): 5.5
# Epoch 21/25: [*****] Val Loss: 0.0704, Val Acc: 0.9807 Elapsed (sec): 5.4
# Epoch 22/25: [*****] Val Loss: 0.0806, Val Acc: 0.9792 Elapsed (sec): 5.2
# Epoch 23/25: [*****] Val Loss: 0.0709, Val Acc: 0.9814 Elapsed (sec): 5.5
# Epoch 24/25: [*****] Val Loss: 0.0738, Val Acc: 0.9799 Elapsed (sec): 5.5
# Epoch 25/25: [*****] Val Loss: 0.0717, Val Acc: 0.9821 Elapsed (sec): 5.5
# Training RFN: RFN=True, mu=0.1:
# Epoch 1/25: [*****] Val Loss: 0.0806, Val Acc: 0.9762 Elapsed (sec): 10.1
# Epoch 2/25: [*****] Val Loss: 0.0834, Val Acc: 0.9760 Elapsed (sec): 10.3
# Epoch 3/25: [*****] Val Loss: 0.0816, Val Acc: 0.9762 Elapsed (sec): 10.1
# Epoch 4/25: [*****] Val Loss: 0.0794, Val Acc: 0.9784 Elapsed (sec): 10.3
# Epoch 5/25: [*****] Val Loss: 0.0803, Val Acc: 0.9779 Elapsed (sec): 10.3
# Epoch 6/25: [*****] Val Loss: 0.0757, Val Acc: 0.9792 Elapsed (sec): 10.0
# Epoch 7/25: [*****] Val Loss: 0.0806, Val Acc: 0.9778 Elapsed (sec): 10.5
# Epoch 8/25: [*****] Val Loss: 0.0787, Val Acc: 0.9781 Elapsed (sec): 10.1
# Epoch 9/25: [*****] Val Loss: 0.0767, Val Acc: 0.9806 Elapsed (sec): 10.3
# Epoch 10/25: [*****] Val Loss: 0.0807, Val Acc: 0.9772 Elapsed (sec): 10.3
# Epoch 11/25: [*****] Val Loss: 0.0841, Val Acc: 0.9782 Elapsed (sec): 10.2
# Epoch 12/25: [*****] Val Loss: 0.0784, Val Acc: 0.9797 Elapsed (sec): 10.3
# Epoch 13/25: [*****] Val Loss: 0.0775, Val Acc: 0.9803 Elapsed (sec): 10.0
# Epoch 14/25: [*****] Val Loss: 0.0801, Val Acc: 0.9798 Elapsed (sec): 10.3
# Epoch 15/25: [*****] Val Loss: 0.0937, Val Acc: 0.9752 Elapsed (sec): 10.5
# Epoch 16/25: [*****] Val Loss: 0.0851, Val Acc: 0.9779 Elapsed (sec): 10.2
# Epoch 17/25: [*****] Val Loss: 0.0780, Val Acc: 0.9804 Elapsed (sec): 10.3
# Epoch 18/25: [*****] Val Loss: 0.0849, Val Acc: 0.9782 Elapsed (sec): 10.0
# Epoch 19/25: [*****] Val Loss: 0.0796, Val Acc: 0.9796 Elapsed (sec): 10.6
# Epoch 20/25: [*****] Val Loss: 0.0784, Val Acc: 0.9808 Elapsed (sec): 10.3
# Epoch 21/25: [*****] Val Loss: 0.0873, Val Acc: 0.9792 Elapsed (sec): 10.3
# Epoch 22/25: [*****] Val Loss: 0.0820, Val Acc: 0.9795 Elapsed (sec): 10.5
# Epoch 23/25: [*****] Val Loss: 0.0811, Val Acc: 0.9788 Elapsed (sec): 10.0
# Epoch 24/25: [*****] Val Loss: 0.0768, Val Acc: 0.9794 Elapsed (sec): 10.4
# Epoch 25/25: [*****] Val Loss: 0.0819, Val Acc: 0.9802 Elapsed (sec): 10.2
# Training RFN: RFN=True, mu=0.2:
# Epoch 1/25: [*****] Val Loss: 0.0901, Val Acc: 0.9743 Elapsed (sec): 10.3
# Epoch 2/25: [*****] Val Loss: 0.0801, Val Acc: 0.9780 Elapsed (sec): 10.3
# Epoch 3/25: [*****] Val Loss: 0.0912, Val Acc: 0.9752 Elapsed (sec): 10.0
# Epoch 4/25: [*****] Val Loss: 0.0822, Val Acc: 0.9774 Elapsed (sec): 10.3
# Epoch 5/25: [*****] Val Loss: 0.0865, Val Acc: 0.9761 Elapsed (sec): 10.1
# Epoch 6/25: [*****] Val Loss: 0.0909, Val Acc: 0.9756 Elapsed (sec): 10.5
# Epoch 7/25: [*****] Val Loss: 0.0839, Val Acc: 0.9768 Elapsed (sec): 10.4
# Epoch 8/25: [*****] Val Loss: 0.0840, Val Acc: 0.9779 Elapsed (sec): 10.1
# Epoch 9/25: [*****] Val Loss: 0.0822, Val Acc: 0.9798 Elapsed (sec): 10.5
# Epoch 10/25: [*****] Val Loss: 0.0844, Val Acc: 0.9767 Elapsed (sec): 10.0
# Epoch 11/25: [*****] Val Loss: 0.0820, Val Acc: 0.9791 Elapsed (sec): 10.3
# Epoch 12/25: [*****] Val Loss: 0.0845, Val Acc: 0.9785 Elapsed (sec): 10.3
# Epoch 13/25: [*****] Val Loss: 0.0859, Val Acc: 0.9786 Elapsed (sec): 10.2
# Epoch 14/25: [*****] Val Loss: 0.0889, Val Acc: 0.9773 Elapsed (sec): 10.3
# Epoch 15/25: [*****] Val Loss: 0.0806, Val Acc: 0.9796 Elapsed (sec): 10.0
# Epoch 16/25: [*****] Val Loss: 0.0830, Val Acc: 0.9776 Elapsed (sec): 10.3
# Epoch 17/25: [*****] Val Loss: 0.0843, Val Acc: 0.9776 Elapsed (sec): 10.4
# Epoch 18/25: [*****] Val Loss: 0.0903, Val Acc: 0.9780 Elapsed (sec): 10.3
# Epoch 19/25: [*****] Val Loss: 0.0932, Val Acc: 0.9767 Elapsed (sec): 10.3
# Epoch 20/25: [*****] Val Loss: 0.0823, Val Acc: 0.9786 Elapsed (sec): 10.0
# Epoch 21/25: [*****] Val Loss: 0.0836, Val Acc: 0.9782 Elapsed (sec): 10.5
# Epoch 22/25: [*****] Val Loss: 0.0898, Val Acc: 0.9798 Elapsed (sec): 10.2
# Epoch 23/25: [*****] Val Loss: 0.0805, Val Acc: 0.9793 Elapsed (sec): 10.5
# Epoch 24/25: [*****] Val Loss: 0.0840, Val Acc: 0.9792 Elapsed (sec): 10.4
# Epoch 25/25: [*****] Val Loss: 0.0918, Val Acc: 0.9775 Elapsed (sec): 10.0
# Training RFN: RFN=True, mu=0.3:
# Epoch 1/25: [*****] Val Loss: 0.0942, Val Acc: 0.9732 Elapsed (sec): 10.3
# Epoch 2/25: [*****] Val Loss: 0.0866, Val Acc: 0.9748 Elapsed (sec): 10.1
# Epoch 3/25: [*****] Val Loss: 0.0799, Val Acc: 0.9776 Elapsed (sec): 10.3
# Epoch 4/25: [*****] Val Loss: 0.0839, Val Acc: 0.9774 Elapsed (sec): 10.3
# Epoch 5/25: [*****] Val Loss: 0.0902, Val Acc: 0.9758 Elapsed (sec): 10.1
# Epoch 6/25: [*****] Val Loss: 0.0930, Val Acc: 0.9738 Elapsed (sec): 10.4
# Epoch 7/25: [*****] Val Loss: 0.0839, Val Acc: 0.9768 Elapsed (sec): 10.1
# Epoch 8/25: [*****] Val Loss: 0.0907, Val Acc: 0.9748 Elapsed (sec): 10.4
# Epoch 9/25: [*****] Val Loss: 0.0862, Val Acc: 0.9768 Elapsed (sec): 10.3
# Epoch 10/25: [*****] Val Loss: 0.0895, Val Acc: 0.9748 Elapsed (sec): 10.2
# Epoch 11/25: [*****] Val Loss: 0.0870, Val Acc: 0.9769 Elapsed (sec): 10.4
# Epoch 12/25: [*****] Val Loss: 0.0917, Val Acc: 0.9762 Elapsed (sec): 10.1
# Epoch 13/25: [*****] Val Loss: 0.0894, Val Acc: 0.9778 Elapsed (sec): 13.9
# Epoch 14/25: [*****] Val Loss: 0.0878, Val Acc: 0.9785 Elapsed (sec): 17.9
# Epoch 15/25: [*****] Val Loss: 0.0865, Val Acc: 0.9764 Elapsed (sec): 17.4
# Epoch 16/25: [*****] Val Loss: 0.0912, Val Acc: 0.9761 Elapsed (sec): 17.8
# Epoch 17/25: [*****] Val Loss: 0.0902, Val Acc: 0.9760 Elapsed (sec): 18.3
# Epoch 18/25: [*****] Val Loss: 0.0809, Val Acc: 0.9771 Elapsed (sec): 17.4
# Epoch 19/25: [*****] Val Loss: 0.0825, Val Acc: 0.9782 Elapsed (sec): 18.1
# Epoch 20/25: [*****] Val Loss: 0.0841, Val Acc: 0.9778 Elapsed (sec): 18.0
# Epoch 21/25: [*****] Val Loss: 0.0805, Val Acc: 0.9789 Elapsed (sec): 18.0
# Epoch 22/25: [*****] Val Loss: 0.0847, Val Acc: 0.9768 Elapsed (sec): 18.1
# Epoch 23/25: [*****] Val Loss: 0.0853, Val Acc: 0.9776 Elapsed (sec): 18.7
# Epoch 24/25: [*****] Val Loss: 0.0859, Val Acc: 0.9772 Elapsed (sec): 18.5
# Epoch 25/25: [*****] Val Loss: 0.0836, Val Acc: 0.9779 Elapsed (sec): 19.0
# Training RFN: RFN=True, mu=0.4:
# Epoch 1/25: [*****] Val Loss: 0.1014, Val Acc: 0.9730 Elapsed (sec): 17.9
# Epoch 2/25: [*****] Val Loss: 0.1016, Val Acc: 0.9716 Elapsed (sec): 18.6
# Epoch 3/25: [*****] Val Loss: 0.0955, Val Acc: 0.9722 Elapsed (sec): 18.1
# Epoch 4/25: [*****] Val Loss: 0.0966, Val Acc: 0.9726 Elapsed (sec): 18.8
# Epoch 5/25: [*****] Val Loss: 0.0930, Val Acc: 0.9742 Elapsed (sec): 18.2
# Epoch 6/25: [*****] Val Loss: 0.0954, Val Acc: 0.9714 Elapsed (sec): 19.1
# Epoch 7/25: [*****] Val Loss: 0.1003, Val Acc: 0.9715 Elapsed (sec): 22.1
# Epoch 8/25: [*****] Val Loss: 0.1037, Val Acc: 0.9718 Elapsed (sec): 21.2
# Epoch 9/25: [*****] Val Loss: 0.0907, Val Acc: 0.9732 Elapsed (sec): 20.2
# Epoch 10/25: [*****] Val Loss: 0.0952, Val Acc: 0.9739 Elapsed (sec): 21.1
# Epoch 11/25: [*****] Val Loss: 0.0961, Val Acc: 0.9732 Elapsed (sec): 19.7
# Epoch 12/25: [*****] Val Loss: 0.1052, Val Acc: 0.9695 Elapsed (sec): 19.6
# Epoch 13/25: [*****] Val Loss: 0.0983, Val Acc: 0.9718 Elapsed (sec): 17.9
# Epoch 14/25: [*****] Val Loss: 0.0925, Val Acc: 0.9747 Elapsed (sec): 17.4
# Epoch 15/25: [*****] Val Loss: 0.0982, Val Acc: 0.9736 Elapsed (sec): 16.8
# Epoch 16/25: [*****] Val Loss: 0.0937, Val Acc: 0.9748 Elapsed (sec): 17.2
# Epoch 17/25: [*****] Val Loss: 0.0959, Val Acc: 0.9734 Elapsed (sec): 16.8
# Epoch 18/25: [*****] Val Loss: 0.0980, Val Acc: 0.9728 Elapsed (sec): 16.8
# Epoch 19/25: [*****] Val Loss: 0.0973, Val Acc: 0.9734 Elapsed (sec): 16.6
# Epoch 20/25: [*****] Val Loss: 0.0904, Val Acc: 0.9739 Elapsed (sec): 17.5
# Epoch 21/25: [*****] Val Loss: 0.0935, Val Acc: 0.9732 Elapsed (sec): 17.8
# Epoch 22/25: [*****] Val Loss: 0.0891, Val Acc: 0.9752 Elapsed (sec): 17.0
# Epoch 23/25: [*****] Val Loss: 0.0883, Val Acc: 0.9750 Elapsed (sec): 17.2
# Epoch 24/25: [*****] Val Loss: 0.0982, Val Acc: 0.9728 Elapsed (sec): 16.8
# Epoch 25/25: [*****] Val Loss: 0.0895, Val Acc: 0.9745 Elapsed (sec): 19.5
# Training RFN: RFN=True, mu=0.5:
# Epoch 1/25: [*****] Val Loss: 0.1112, Val Acc: 0.9681 Elapsed (sec): 17.3
# Epoch 2/25: [*****] Val Loss: 0.1033, Val Acc: 0.9674 Elapsed (sec): 17.2
# Epoch 3/25: [*****] Val Loss: 0.1082, Val Acc: 0.9682 Elapsed (sec): 17.5
# Epoch 4/25: [*****] Val Loss: 0.1226, Val Acc: 0.9642 Elapsed (sec): 18.3
# Epoch 5/25: [*****] Val Loss: 0.1068, Val Acc: 0.9700 Elapsed (sec): 17.9
# Epoch 6/25: [*****] Val Loss: 0.1108, Val Acc: 0.9685 Elapsed (sec): 17.8
# Epoch 7/25: [*****] Val Loss: 0.1063, Val Acc: 0.9688 Elapsed (sec): 16.7
# Epoch 8/25: [*****] Val Loss: 0.1090, Val Acc: 0.9666 Elapsed (sec): 15.5
# Epoch 9/25: [*****] Val Loss: 0.1053, Val Acc: 0.9674 Elapsed (sec): 15.6
# Epoch 10/25: [*****] Val Loss: 0.0999, Val Acc: 0.9712 Elapsed (sec): 19.6
# Epoch 11/25: [*****] Val Loss: 0.0998, Val Acc: 0.9702 Elapsed (sec): 20.5
# Epoch 12/25: [*****] Val Loss: 0.1077, Val Acc: 0.9690 Elapsed (sec): 18.6
# Epoch 13/25: [*****] Val Loss: 0.0983, Val Acc: 0.9701 Elapsed (sec): 19.7
# Epoch 14/25: [*****] Val Loss: 0.1019, Val Acc: 0.9687 Elapsed (sec): 19.6
# Epoch 15/25: [*****] Val Loss: 0.1114, Val Acc: 0.9666 Elapsed (sec): 19.8
# Epoch 16/25: [*****] Val Loss: 0.1057, Val Acc: 0.9678 Elapsed (sec): 19.4
# Epoch 17/25: [*****] Val Loss: 0.1005, Val Acc: 0.9711 Elapsed (sec): 19.7
# Epoch 18/25: [*****] Val Loss: 0.0952, Val Acc: 0.9710 Elapsed (sec): 18.0
# Epoch 19/25: [*****] Val Loss: 0.1007, Val Acc: 0.9700 Elapsed (sec): 19.6
# Epoch 20/25: [*****] Val Loss: 0.1067, Val Acc: 0.9690 Elapsed (sec): 19.2
# Epoch 21/25: [*****] Val Loss: 0.1078, Val Acc: 0.9685 Elapsed (sec): 19.1
# Epoch 22/25: [*****] Val Loss: 0.1013, Val Acc: 0.9701 Elapsed (sec): 20.1
# Epoch 23/25: [*****] Val Loss: 0.0984, Val Acc: 0.9713 Elapsed (sec): 18.1
# Epoch 24/25: [*****] Val Loss: 0.1007, Val Acc: 0.9704 Elapsed (sec): 17.9
# Epoch 25/25: [*****] Val Loss: 0.0942, Val Acc: 0.9730 Elapsed (sec): 17.3

# %%
import pickle
with open('./models/train25_mnist_history.pkl', 'wb') as f:
    pickle.dump(history, f)

# %%
with open('./models/train25_mnist_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
import matplotlib.pyplot as plt

colors = ['k', 'r', 'b', 'g', 'm', 'c']
linestyles = ['-', '-.', '--'] #Standard=solid, Dropout=dashdot, RFN=dash

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
fig.suptitle('MNIST Training History')
ax[0].set_title('Validation Accuracy')
ax[1].set_title('Validation Loss')
for linestyle, model_name in zip(linestyles, models.keys()):
    for color, (mu, vals) in zip(colors, history[model_name].items()):
        try:
            acc, loss = vals
            ax[0].plot(range(len(acc)), acc, color+linestyle, label=f'{model_name}: {mu}')
            ax[1].plot(range(len(loss)), loss, color+linestyle, label=f'{model_name}: {mu}')
        except:
            continue
ax[0].legend(title='Model: RFN Rate')
ax[1].legend(title='Model: RFN Rate')

# %% [markdown]
# #### Train Standard, Dropout, and RFN models at 25 epochs each on full trainset eval on test set

# %%
# Create dictionary to store training history for all models
models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]

history = {}
for model_name in models.keys():
    history[model_name] = {}
    for mu in rfn_mu_vals:
        history[model_name][mu] = {}

# %%
# Train Standard, Dropout, and RFN MNIST model using paper hyperparameters
# Train on full train data, eval on test data using epochs = 25

models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]
epochs = 25

for model_name, model_instance in models.items():
    print()
    for mu in rfn_mu_vals:    
        # Set whether RFN will be used in training
        if mu == 0:
            rfn_flag = False
        else:
            rfn_flag = True
        
        # Standard and Dropout models don't need to be trained with RFN
        if model_name != 'RFN' and mu != 0:
            print(f'Skip {model_name} at mu={mu}')
            continue
            
        print(f'Training {model_name}: RFN={rfn_flag}, mu={mu}:')     
        model = model_instance
        model.to(device)
        rfn_wrapper = RFN(model, mu=mu, sigma=.05, rfn_flag=rfn_flag)
        rfn_wrapper.to(device)

        loss_func = nn.CrossEntropyLoss()
        opt = optim.SGD(model.parameters(), lr=0.1) # Opt and LR per paper
        
        # Save tuple of epoch val accuracy and val loss to history dict
        history[model_name][mu] = fit(epochs, rfn_wrapper, loss_func, opt, full_train_dl, test_dl)

        # Save model
        PATH = f'./models/Full_MNIST_{model_name}_{mu}.pth'
        torch.save(model.state_dict(), PATH)
# Out:
# Training Standard: RFN=False, mu=0:
# Epoch 1/25: [*******] Val Loss: 0.3087, Val Acc: 0.9104 Elapsed (sec): 4.3
# Epoch 2/25: [*******] Val Loss: 0.1857, Val Acc: 0.9429 Elapsed (sec): 4.5
# Epoch 3/25: [*******] Val Loss: 0.1266, Val Acc: 0.9613 Elapsed (sec): 4.5
# Epoch 4/25: [*******] Val Loss: 0.1007, Val Acc: 0.9683 Elapsed (sec): 4.4
# Epoch 5/25: [*******] Val Loss: 0.0962, Val Acc: 0.9710 Elapsed (sec): 4.5
# Epoch 6/25: [*******] Val Loss: 0.0990, Val Acc: 0.9682 Elapsed (sec): 4.5
# Epoch 7/25: [*******] Val Loss: 0.0795, Val Acc: 0.9739 Elapsed (sec): 4.6
# Epoch 8/25: [*******] Val Loss: 0.0748, Val Acc: 0.9764 Elapsed (sec): 4.3
# Epoch 9/25: [*******] Val Loss: 0.0771, Val Acc: 0.9765 Elapsed (sec): 4.3
# Epoch 10/25: [*******] Val Loss: 0.0723, Val Acc: 0.9766 Elapsed (sec): 4.3
# Epoch 11/25: [*******] Val Loss: 0.0632, Val Acc: 0.9812 Elapsed (sec): 4.4
# Epoch 12/25: [*******] Val Loss: 0.0654, Val Acc: 0.9801 Elapsed (sec): 4.4
# Epoch 13/25: [*******] Val Loss: 0.0677, Val Acc: 0.9792 Elapsed (sec): 4.5
# Epoch 14/25: [*******] Val Loss: 0.0635, Val Acc: 0.9807 Elapsed (sec): 4.5
# Epoch 15/25: [*******] Val Loss: 0.0672, Val Acc: 0.9801 Elapsed (sec): 4.3
# Epoch 16/25: [*******] Val Loss: 0.0622, Val Acc: 0.9818 Elapsed (sec): 4.5
# Epoch 17/25: [*******] Val Loss: 0.0802, Val Acc: 0.9779 Elapsed (sec): 4.4
# Epoch 18/25: [*******] Val Loss: 0.0670, Val Acc: 0.9814 Elapsed (sec): 4.3
# Epoch 19/25: [*******] Val Loss: 0.0666, Val Acc: 0.9817 Elapsed (sec): 4.3
# Epoch 20/25: [*******] Val Loss: 0.0655, Val Acc: 0.9823 Elapsed (sec): 4.3
# Epoch 21/25: [*******] Val Loss: 0.0678, Val Acc: 0.9811 Elapsed (sec): 4.3
# Epoch 22/25: [*******] Val Loss: 0.0685, Val Acc: 0.9814 Elapsed (sec): 4.6
# Epoch 23/25: [*******] Val Loss: 0.0693, Val Acc: 0.9807 Elapsed (sec): 4.3
# Epoch 24/25: [*******] Val Loss: 0.0694, Val Acc: 0.9815 Elapsed (sec): 4.4
# Epoch 25/25: [*******] Val Loss: 0.0701, Val Acc: 0.9817 Elapsed (sec): 4.3
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
#
# Training Dropout: RFN=False, mu=0:
# Epoch 1/25: [*******] Val Loss: 0.2975, Val Acc: 0.9095 Elapsed (sec): 4.3
# Epoch 2/25: [*******] Val Loss: 0.1644, Val Acc: 0.9497 Elapsed (sec): 4.5
# Epoch 3/25: [*******] Val Loss: 0.1317, Val Acc: 0.9595 Elapsed (sec): 4.5
# Epoch 4/25: [*******] Val Loss: 0.1251, Val Acc: 0.9608 Elapsed (sec): 4.4
# Epoch 5/25: [*******] Val Loss: 0.1059, Val Acc: 0.9654 Elapsed (sec): 4.3
# Epoch 6/25: [*******] Val Loss: 0.0786, Val Acc: 0.9745 Elapsed (sec): 4.3
# Epoch 7/25: [*******] Val Loss: 0.0703, Val Acc: 0.9780 Elapsed (sec): 4.3
# Epoch 8/25: [*******] Val Loss: 0.0728, Val Acc: 0.9763 Elapsed (sec): 4.3
# Epoch 9/25: [*******] Val Loss: 0.1075, Val Acc: 0.9656 Elapsed (sec): 4.3
# Epoch 10/25: [*******] Val Loss: 0.0659, Val Acc: 0.9797 Elapsed (sec): 4.3
# Epoch 11/25: [*******] Val Loss: 0.0640, Val Acc: 0.9785 Elapsed (sec): 4.3
# Epoch 12/25: [*******] Val Loss: 0.0643, Val Acc: 0.9804 Elapsed (sec): 4.3
# Epoch 13/25: [*******] Val Loss: 0.0637, Val Acc: 0.9802 Elapsed (sec): 4.7
# Epoch 14/25: [*******] Val Loss: 0.0681, Val Acc: 0.9798 Elapsed (sec): 4.3
# Epoch 15/25: [*******] Val Loss: 0.0644, Val Acc: 0.9794 Elapsed (sec): 4.5
# Epoch 16/25: [*******] Val Loss: 0.0690, Val Acc: 0.9804 Elapsed (sec): 4.3
# Epoch 17/25: [*******] Val Loss: 0.0659, Val Acc: 0.9812 Elapsed (sec): 4.3
# Epoch 18/25: [*******] Val Loss: 0.0702, Val Acc: 0.9802 Elapsed (sec): 4.3
# Epoch 19/25: [*******] Val Loss: 0.0726, Val Acc: 0.9800 Elapsed (sec): 4.3
# Epoch 20/25: [*******] Val Loss: 0.0669, Val Acc: 0.9815 Elapsed (sec): 4.3
# Epoch 21/25: [*******] Val Loss: 0.0718, Val Acc: 0.9823 Elapsed (sec): 4.3
# Epoch 22/25: [*******] Val Loss: 0.0686, Val Acc: 0.9825 Elapsed (sec): 4.3
# Epoch 23/25: [*******] Val Loss: 0.0711, Val Acc: 0.9827 Elapsed (sec): 4.3
# Epoch 24/25: [*******] Val Loss: 0.0723, Val Acc: 0.9814 Elapsed (sec): 4.3
# Epoch 25/25: [*******] Val Loss: 0.0706, Val Acc: 0.9821 Elapsed (sec): 4.3
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
#
# Training RFN: RFN=False, mu=0:
# Epoch 1/25: [*******] Val Loss: 0.2987, Val Acc: 0.9129 Elapsed (sec): 4.3
# Epoch 2/25: [*******] Val Loss: 0.1762, Val Acc: 0.9465 Elapsed (sec): 4.4
# Epoch 3/25: [*******] Val Loss: 0.1231, Val Acc: 0.9610 Elapsed (sec): 4.3
# Epoch 4/25: [*******] Val Loss: 0.1013, Val Acc: 0.9687 Elapsed (sec): 4.3
# Epoch 5/25: [*******] Val Loss: 0.0961, Val Acc: 0.9690 Elapsed (sec): 4.3
# Epoch 6/25: [*******] Val Loss: 0.0839, Val Acc: 0.9735 Elapsed (sec): 4.3
# Epoch 7/25: [*******] Val Loss: 0.0763, Val Acc: 0.9755 Elapsed (sec): 4.3
# Epoch 8/25: [*******] Val Loss: 0.0657, Val Acc: 0.9781 Elapsed (sec): 4.3
# Epoch 9/25: [*******] Val Loss: 0.0742, Val Acc: 0.9760 Elapsed (sec): 4.4
# Epoch 10/25: [*******] Val Loss: 0.0690, Val Acc: 0.9778 Elapsed (sec): 4.4
# Epoch 11/25: [*******] Val Loss: 0.0679, Val Acc: 0.9793 Elapsed (sec): 4.3
# Epoch 12/25: [*******] Val Loss: 0.0677, Val Acc: 0.9781 Elapsed (sec): 4.4
# Epoch 13/25: [*******] Val Loss: 0.0626, Val Acc: 0.9808 Elapsed (sec): 4.3
# Epoch 14/25: [*******] Val Loss: 0.0664, Val Acc: 0.9805 Elapsed (sec): 4.4
# Epoch 15/25: [*******] Val Loss: 0.0635, Val Acc: 0.9807 Elapsed (sec): 4.3
# Epoch 16/25: [*******] Val Loss: 0.0593, Val Acc: 0.9828 Elapsed (sec): 4.3
# Epoch 17/25: [*******] Val Loss: 0.0659, Val Acc: 0.9809 Elapsed (sec): 4.3
# Epoch 18/25: [*******] Val Loss: 0.0651, Val Acc: 0.9812 Elapsed (sec): 4.4
# Epoch 19/25: [*******] Val Loss: 0.0623, Val Acc: 0.9834 Elapsed (sec): 4.4
# Epoch 20/25: [*******] Val Loss: 0.0690, Val Acc: 0.9816 Elapsed (sec): 4.4
# Epoch 21/25: [*******] Val Loss: 0.0673, Val Acc: 0.9819 Elapsed (sec): 4.4
# Epoch 22/25: [*******] Val Loss: 0.0674, Val Acc: 0.9827 Elapsed (sec): 4.4
# Epoch 23/25: [*******] Val Loss: 0.0691, Val Acc: 0.9818 Elapsed (sec): 4.3
# Epoch 24/25: [*******] Val Loss: 0.0670, Val Acc: 0.9833 Elapsed (sec): 4.4
# Epoch 25/25: [*******] Val Loss: 0.0707, Val Acc: 0.9823 Elapsed (sec): 4.3
# Training RFN: RFN=True, mu=0.1:
# Epoch 1/25: [*******] Val Loss: 0.0808, Val Acc: 0.9746 Elapsed (sec): 9.1
# Epoch 2/25: [*******] Val Loss: 0.0812, Val Acc: 0.9762 Elapsed (sec): 8.6
# Epoch 3/25: [*******] Val Loss: 0.0770, Val Acc: 0.9779 Elapsed (sec): 8.6
# Epoch 4/25: [*******] Val Loss: 0.0825, Val Acc: 0.9783 Elapsed (sec): 8.7
# Epoch 5/25: [*******] Val Loss: 0.0827, Val Acc: 0.9780 Elapsed (sec): 8.6
# Epoch 6/25: [*******] Val Loss: 0.0688, Val Acc: 0.9805 Elapsed (sec): 8.6
# Epoch 7/25: [*******] Val Loss: 0.0744, Val Acc: 0.9781 Elapsed (sec): 8.6
# Epoch 8/25: [*******] Val Loss: 0.0772, Val Acc: 0.9794 Elapsed (sec): 8.7
# Epoch 9/25: [*******] Val Loss: 0.0740, Val Acc: 0.9803 Elapsed (sec): 8.7
# Epoch 10/25: [*******] Val Loss: 0.0676, Val Acc: 0.9827 Elapsed (sec): 9.0
# Epoch 11/25: [*******] Val Loss: 0.0753, Val Acc: 0.9800 Elapsed (sec): 9.9
# Epoch 12/25: [*******] Val Loss: 0.0675, Val Acc: 0.9828 Elapsed (sec): 10.2
# Epoch 13/25: [*******] Val Loss: 0.0753, Val Acc: 0.9801 Elapsed (sec): 10.3
# Epoch 14/25: [*******] Val Loss: 0.0772, Val Acc: 0.9816 Elapsed (sec): 10.6
# Epoch 15/25: [*******] Val Loss: 0.0773, Val Acc: 0.9797 Elapsed (sec): 10.3
# Epoch 16/25: [*******] Val Loss: 0.0814, Val Acc: 0.9788 Elapsed (sec): 10.0
# Epoch 17/25: [*******] Val Loss: 0.0688, Val Acc: 0.9819 Elapsed (sec): 10.5
# Epoch 18/25: [*******] Val Loss: 0.0741, Val Acc: 0.9808 Elapsed (sec): 10.5
# Epoch 19/25: [*******] Val Loss: 0.0734, Val Acc: 0.9822 Elapsed (sec): 10.3
# Epoch 20/25: [*******] Val Loss: 0.0775, Val Acc: 0.9797 Elapsed (sec): 9.6
# Epoch 21/25: [*******] Val Loss: 0.0724, Val Acc: 0.9825 Elapsed (sec): 10.8
# Epoch 22/25: [*******] Val Loss: 0.0683, Val Acc: 0.9821 Elapsed (sec): 10.7
# Epoch 23/25: [*******] Val Loss: 0.0709, Val Acc: 0.9815 Elapsed (sec): 9.3
# Epoch 24/25: [*******] Val Loss: 0.0691, Val Acc: 0.9825 Elapsed (sec): 10.2
# Epoch 25/25: [*******] Val Loss: 0.0739, Val Acc: 0.9820 Elapsed (sec): 10.8
# Training RFN: RFN=True, mu=0.2:
# Epoch 1/25: [*******] Val Loss: 0.0876, Val Acc: 0.9764 Elapsed (sec): 10.4
# Epoch 2/25: [*******] Val Loss: 0.0776, Val Acc: 0.9784 Elapsed (sec): 10.7
# Epoch 3/25: [*******] Val Loss: 0.0705, Val Acc: 0.9804 Elapsed (sec): 8.8
# Epoch 4/25: [*******] Val Loss: 0.0790, Val Acc: 0.9765 Elapsed (sec): 9.9
# Epoch 5/25: [*******] Val Loss: 0.0794, Val Acc: 0.9790 Elapsed (sec): 10.5
# Epoch 6/25: [*******] Val Loss: 0.0853, Val Acc: 0.9764 Elapsed (sec): 10.5
# Epoch 7/25: [*******] Val Loss: 0.0743, Val Acc: 0.9776 Elapsed (sec): 10.5
# Epoch 8/25: [*******] Val Loss: 0.0777, Val Acc: 0.9791 Elapsed (sec): 10.5
# Epoch 9/25: [*******] Val Loss: 0.0719, Val Acc: 0.9804 Elapsed (sec): 10.8
# Epoch 10/25: [*******] Val Loss: 0.0796, Val Acc: 0.9786 Elapsed (sec): 10.8
# Epoch 11/25: [*******] Val Loss: 0.0788, Val Acc: 0.9801 Elapsed (sec): 10.9
# Epoch 12/25: [*******] Val Loss: 0.0742, Val Acc: 0.9808 Elapsed (sec): 10.4
# Epoch 13/25: [*******] Val Loss: 0.0746, Val Acc: 0.9807 Elapsed (sec): 10.4
# Epoch 14/25: [*******] Val Loss: 0.0775, Val Acc: 0.9796 Elapsed (sec): 11.2
# Epoch 15/25: [*******] Val Loss: 0.0723, Val Acc: 0.9804 Elapsed (sec): 10.6
# Epoch 16/25: [*******] Val Loss: 0.0774, Val Acc: 0.9805 Elapsed (sec): 9.6
# Epoch 17/25: [*******] Val Loss: 0.0758, Val Acc: 0.9816 Elapsed (sec): 10.7
# Epoch 18/25: [*******] Val Loss: 0.0797, Val Acc: 0.9789 Elapsed (sec): 10.5
# Epoch 19/25: [*******] Val Loss: 0.0763, Val Acc: 0.9803 Elapsed (sec): 10.3
# Epoch 20/25: [*******] Val Loss: 0.0750, Val Acc: 0.9807 Elapsed (sec): 10.4
# Epoch 21/25: [*******] Val Loss: 0.0885, Val Acc: 0.9781 Elapsed (sec): 9.8
# Epoch 22/25: [*******] Val Loss: 0.0709, Val Acc: 0.9816 Elapsed (sec): 10.3
# Epoch 23/25: [*******] Val Loss: 0.0710, Val Acc: 0.9822 Elapsed (sec): 10.9
# Epoch 24/25: [*******] Val Loss: 0.0743, Val Acc: 0.9818 Elapsed (sec): 10.6
# Epoch 25/25: [*******] Val Loss: 0.0722, Val Acc: 0.9825 Elapsed (sec): 9.9
# Training RFN: RFN=True, mu=0.3:
# Epoch 1/25: [*******] Val Loss: 0.0794, Val Acc: 0.9759 Elapsed (sec): 10.5
# Epoch 2/25: [*******] Val Loss: 0.0914, Val Acc: 0.9750 Elapsed (sec): 10.6
# Epoch 3/25: [*******] Val Loss: 0.0893, Val Acc: 0.9761 Elapsed (sec): 9.1
# Epoch 4/25: [*******] Val Loss: 0.0880, Val Acc: 0.9753 Elapsed (sec): 9.2
# Epoch 5/25: [*******] Val Loss: 0.0819, Val Acc: 0.9771 Elapsed (sec): 9.3
# Epoch 6/25: [*******] Val Loss: 0.0852, Val Acc: 0.9758 Elapsed (sec): 9.7
# Epoch 7/25: [*******] Val Loss: 0.0811, Val Acc: 0.9767 Elapsed (sec): 11.0
# Epoch 8/25: [*******] Val Loss: 0.0847, Val Acc: 0.9774 Elapsed (sec): 11.0
# Epoch 9/25: [*******] Val Loss: 0.0739, Val Acc: 0.9798 Elapsed (sec): 10.2
# Epoch 10/25: [*******] Val Loss: 0.0836, Val Acc: 0.9765 Elapsed (sec): 9.6
# Epoch 11/25: [*******] Val Loss: 0.0784, Val Acc: 0.9783 Elapsed (sec): 11.2
# Epoch 12/25: [*******] Val Loss: 0.0887, Val Acc: 0.9771 Elapsed (sec): 10.4
# Epoch 13/25: [*******] Val Loss: 0.0788, Val Acc: 0.9798 Elapsed (sec): 9.2
# Epoch 14/25: [*******] Val Loss: 0.0769, Val Acc: 0.9785 Elapsed (sec): 9.8
# Epoch 15/25: [*******] Val Loss: 0.0751, Val Acc: 0.9771 Elapsed (sec): 9.9
# Epoch 16/25: [*******] Val Loss: 0.0760, Val Acc: 0.9793 Elapsed (sec): 9.7
# Epoch 17/25: [*******] Val Loss: 0.0792, Val Acc: 0.9787 Elapsed (sec): 10.6
# Epoch 18/25: [*******] Val Loss: 0.0836, Val Acc: 0.9774 Elapsed (sec): 9.5
# Epoch 19/25: [*******] Val Loss: 0.0738, Val Acc: 0.9791 Elapsed (sec): 10.2
# Epoch 20/25: [*******] Val Loss: 0.0756, Val Acc: 0.9803 Elapsed (sec): 10.4
# Epoch 21/25: [*******] Val Loss: 0.0714, Val Acc: 0.9801 Elapsed (sec): 10.7
# Epoch 22/25: [*******] Val Loss: 0.0806, Val Acc: 0.9785 Elapsed (sec): 9.9
# Epoch 23/25: [*******] Val Loss: 0.0774, Val Acc: 0.9784 Elapsed (sec): 10.5
# Epoch 24/25: [*******] Val Loss: 0.0681, Val Acc: 0.9792 Elapsed (sec): 9.8
# Epoch 25/25: [*******] Val Loss: 0.0805, Val Acc: 0.9773 Elapsed (sec): 11.0
# Training RFN: RFN=True, mu=0.4:
# Epoch 1/25: [*******] Val Loss: 0.1011, Val Acc: 0.9724 Elapsed (sec): 9.9
# Epoch 2/25: [*******] Val Loss: 0.0895, Val Acc: 0.9734 Elapsed (sec): 10.4
# Epoch 3/25: [*******] Val Loss: 0.0942, Val Acc: 0.9730 Elapsed (sec): 10.2
# Epoch 4/25: [*******] Val Loss: 0.0911, Val Acc: 0.9736 Elapsed (sec): 10.7
# Epoch 5/25: [*******] Val Loss: 0.0923, Val Acc: 0.9720 Elapsed (sec): 10.6
# Epoch 6/25: [*******] Val Loss: 0.0874, Val Acc: 0.9743 Elapsed (sec): 10.4
# Epoch 7/25: [*******] Val Loss: 0.0856, Val Acc: 0.9748 Elapsed (sec): 10.6
# Epoch 8/25: [*******] Val Loss: 0.0863, Val Acc: 0.9732 Elapsed (sec): 10.8
# Epoch 9/25: [*******] Val Loss: 0.0856, Val Acc: 0.9752 Elapsed (sec): 9.6
# Epoch 10/25: [*******] Val Loss: 0.0849, Val Acc: 0.9765 Elapsed (sec): 10.1
# Epoch 11/25: [*******] Val Loss: 0.0879, Val Acc: 0.9735 Elapsed (sec): 10.8
# Epoch 12/25: [*******] Val Loss: 0.0858, Val Acc: 0.9744 Elapsed (sec): 10.8
# Epoch 13/25: [*******] Val Loss: 0.0845, Val Acc: 0.9769 Elapsed (sec): 10.4
# Epoch 14/25: [*******] Val Loss: 0.0796, Val Acc: 0.9759 Elapsed (sec): 9.5
# Epoch 15/25: [*******] Val Loss: 0.0786, Val Acc: 0.9766 Elapsed (sec): 8.9
# Epoch 16/25: [*******] Val Loss: 0.0771, Val Acc: 0.9765 Elapsed (sec): 8.8
# Epoch 17/25: [*******] Val Loss: 0.0750, Val Acc: 0.9774 Elapsed (sec): 8.7
# Epoch 18/25: [*******] Val Loss: 0.0733, Val Acc: 0.9784 Elapsed (sec): 8.7
# Epoch 19/25: [*******] Val Loss: 0.0803, Val Acc: 0.9763 Elapsed (sec): 8.7
# Epoch 20/25: [*******] Val Loss: 0.0861, Val Acc: 0.9757 Elapsed (sec): 9.3
# Epoch 21/25: [*******] Val Loss: 0.0804, Val Acc: 0.9770 Elapsed (sec): 8.7
# Epoch 22/25: [*******] Val Loss: 0.0773, Val Acc: 0.9784 Elapsed (sec): 8.7
# Epoch 23/25: [*******] Val Loss: 0.0857, Val Acc: 0.9753 Elapsed (sec): 8.7
# Epoch 24/25: [*******] Val Loss: 0.0841, Val Acc: 0.9758 Elapsed (sec): 8.7
# Epoch 25/25: [*******] Val Loss: 0.0852, Val Acc: 0.9760 Elapsed (sec): 8.7
# Training RFN: RFN=True, mu=0.5:
# Epoch 1/25: [*******] Val Loss: 0.0985, Val Acc: 0.9698 Elapsed (sec): 8.7
# Epoch 2/25: [*******] Val Loss: 0.1037, Val Acc: 0.9680 Elapsed (sec): 8.7
# Epoch 3/25: [*******] Val Loss: 0.0964, Val Acc: 0.9703 Elapsed (sec): 9.1
# Epoch 4/25: [*******] Val Loss: 0.1035, Val Acc: 0.9711 Elapsed (sec): 8.7
# Epoch 5/25: [*******] Val Loss: 0.1097, Val Acc: 0.9672 Elapsed (sec): 8.7
# Epoch 6/25: [*******] Val Loss: 0.0969, Val Acc: 0.9696 Elapsed (sec): 8.9
# Epoch 7/25: [*******] Val Loss: 0.0993, Val Acc: 0.9690 Elapsed (sec): 9.6
# Epoch 8/25: [*******] Val Loss: 0.0987, Val Acc: 0.9713 Elapsed (sec): 9.7
# Epoch 9/25: [*******] Val Loss: 0.0941, Val Acc: 0.9736 Elapsed (sec): 8.7
# Epoch 10/25: [*******] Val Loss: 0.0932, Val Acc: 0.9707 Elapsed (sec): 8.7
# Epoch 11/25: [*******] Val Loss: 0.0961, Val Acc: 0.9694 Elapsed (sec): 8.7
# Epoch 12/25: [*******] Val Loss: 0.1041, Val Acc: 0.9695 Elapsed (sec): 8.7
# Epoch 13/25: [*******] Val Loss: 0.0968, Val Acc: 0.9697 Elapsed (sec): 8.7
# Epoch 14/25: [*******] Val Loss: 0.1004, Val Acc: 0.9688 Elapsed (sec): 8.7
# Epoch 15/25: [*******] Val Loss: 0.0991, Val Acc: 0.9710 Elapsed (sec): 8.7
# Epoch 16/25: [*******] Val Loss: 0.0927, Val Acc: 0.9711 Elapsed (sec): 9.3
# Epoch 17/25: [*******] Val Loss: 0.0962, Val Acc: 0.9708 Elapsed (sec): 9.4
# Epoch 18/25: [*******] Val Loss: 0.1018, Val Acc: 0.9687 Elapsed (sec): 8.8
# Epoch 19/25: [*******] Val Loss: 0.0919, Val Acc: 0.9720 Elapsed (sec): 8.7
# Epoch 20/25: [*******] Val Loss: 0.0914, Val Acc: 0.9716 Elapsed (sec): 8.7
# Epoch 21/25: [*******] Val Loss: 0.0931, Val Acc: 0.9717 Elapsed (sec): 8.7
# Epoch 22/25: [*******] Val Loss: 0.0907, Val Acc: 0.9722 Elapsed (sec): 8.7
# Epoch 23/25: [*******] Val Loss: 0.1012, Val Acc: 0.9687 Elapsed (sec): 8.8
# Epoch 24/25: [*******] Val Loss: 0.0970, Val Acc: 0.9683 Elapsed (sec): 8.7
# Epoch 25/25: [*******] Val Loss: 0.0942, Val Acc: 0.9712 Elapsed (sec): 8.7

# %%
import pickle
with open('./models/fulltrain25_mnist_history.pkl', 'wb') as f:
    pickle.dump(history, f)

# %%
with open('./models/fulltrain25_mnist_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
import matplotlib.pyplot as plt

colors = ['k', 'r', 'b', 'g', 'm', 'c']
linestyles = ['-', '-.', '--'] #Standard=solid, Dropout=dashdot, RFN=dash

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,6))
fig.suptitle('MNIST Training History')
ax[0].set_title('Test Accuracy')
ax[1].set_title('Test Loss')
for linestyle, model_name in zip(linestyles, models.keys()):
    for color, (mu, vals) in zip(colors, history[model_name].items()):
        try:
            acc, loss = vals
            ax[0].plot(range(len(acc)), acc, color+linestyle, label=f'{model_name}: {mu}')
            ax[1].plot(range(len(loss)), loss, color+linestyle, label=f'{model_name}: {mu}')
        except:
            continue
ax[0].legend(title='Model: RFN Rate')
ax[1].legend(title='Model: RFN Rate')

# %% [markdown]
# #### Evaluate Models with FSGM Samples

# %%
def fgsm_batch(net, orig, eps=15):
    '''Given a pytorch CNN model, original image as tensor, and value for epsilon, create adversarial sample
    using fast gradient sign method (FGSM) described in arXiv:1412.6572v3'''
    # Create input tensor from original image, unsqeezing by a dim to account for model expected batch dim
    # float cast is likely not needed after normalization, but as float is required for cuda execution,
    # it's best to ensure float data
    inp = orig.float().clone().detach().to(device).requires_grad_(True)
    
    # Make prediction prior to attack to use in calulating gradients
    prior_out = net(inp)
    prior_pred = prior_out.argmax(axis=1)
    
    # Use prediction vector to compute loss and then compute gradients from loss to use in attack
    #loss = criterion(prior_out, prior_pred.unsqueeze(0))
    loss = criterion(prior_out, prior_pred)
    loss.backward()
    
    # Actual FSGM method
    #print(orig.min(), orig.max())
    inp.data = inp.data + ((eps/255.0) * torch.sign(inp.grad.data))
    inp.data = inp.data.clamp(min=orig.min(), max=orig.max())
    #print(inp.min(), inp.max())
    '''
    # Predict on attack sample
    post_pred = torch.argmax(net(inp).data)
    
    # Create perturbation mask
    perturbation = torch.empty_like(orig)
    adv = inp.data.cpu()[0]
    perturbation = adv - orig'''
    
    return inp

# %%
def evaluate(net, dataloader, eps=15, adv=False):
    correct = 0
    count = 0
    for i, data in enumerate(dataloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        if adv:
            inputs = fgsm_batch(net, inputs, eps = eps)
        preds = net(inputs)
        for pred, label in zip(preds, labels):
            if torch.argmax(pred) == label:
                correct += 1.0
            count += 1.0
        if not i % 5000:
            print(f'Sample: {i}, Running Accuracy: {(correct/count):5.3f}')
    acc = correct/count
    print(f'Accuracy over {int(count)} samples: {acc:5.3f}')
    return acc

# %%
# Create accuracy dictionary
models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]
epsilons = [0, 40, 60, 90]

analysis = {}
for model_name in models.keys():
    analysis[model_name] = {}
    for mu in rfn_mu_vals:
        analysis[model_name][mu] = {}
        for eps in epsilons:
            analysis[model_name][mu][eps] = []

# %%
# load CIFAR models
'''val_dl = DataLoader(
    valset, batch_size=1, sampler=val_sampler,
    num_workers=num_workers, pin_memory=pin_memory)
'''
models = {'Standard': MNIST_Standard(), 'Dropout': MNIST_Dropout(), 'RFN': MNIST_RFN()}
rfn_mu_vals = [0, .1, .2, .3, .4, .5]
epsilons = [0, 40, 60, 90]

# Evaluate pretrained CIFAR CNNs with and without FSGM attack, set sigma on RFN = 0 
for model_name, model_instance in models.items():
    print()
    for eps in epsilons:
        if eps == 0:
            adv = False
        else:
            adv = True
        for mu in rfn_mu_vals:
            if mu == 0:
                rfn_flag = False
            else:
                rfn_flag = True
            
            # Standard and Dropout models weren't trained with RFN
            if model_name != 'RFN' and mu != 0:
                print(f'Skip {model_name} at mu={mu}')
                continue

            model = model_instance
            # Set sigma to zero per paper
            rfn_wrapper = RFN(model, mu=mu, sigma=0, rfn_flag=rfn_flag)
            #model.load_state_dict(torch.load(f'./models/MNIST_{model_name}_{mu}.pth'))
            model.load_state_dict(torch.load(f'./models/Full_MNIST_{model_name}_{mu}.pth'))
            model.to(device)
            model.eval()
            criterion = nn.CrossEntropyLoss()

            print(f'Evaluate MNIST {model_name}, eps={eps}, mu={mu}:')
            analysis[model_name][mu][eps] = evaluate(rfn_wrapper, test_dl, eps=eps, adv=adv)
# Out:
# Evaluate MNIST Standard, eps=0, mu=0:
# Sample: 0, Running Accuracy: 1.000
# Accuracy over 10000 samples: 0.982
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
# Evaluate MNIST Standard, eps=40, mu=0:
# Sample: 0, Running Accuracy: 0.125
# Accuracy over 10000 samples: 0.168
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
# Evaluate MNIST Standard, eps=60, mu=0:
# Sample: 0, Running Accuracy: 0.047
# Accuracy over 10000 samples: 0.056
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
# Evaluate MNIST Standard, eps=90, mu=0:
# Sample: 0, Running Accuracy: 0.016
# Accuracy over 10000 samples: 0.023
# Skip Standard at mu=0.1
# Skip Standard at mu=0.2
# Skip Standard at mu=0.3
# Skip Standard at mu=0.4
# Skip Standard at mu=0.5
#
# Evaluate MNIST Dropout, eps=0, mu=0:
# Sample: 0, Running Accuracy: 0.984
# Accuracy over 10000 samples: 0.982
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
# Evaluate MNIST Dropout, eps=40, mu=0:
# Sample: 0, Running Accuracy: 0.133
# Accuracy over 10000 samples: 0.179
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
# Evaluate MNIST Dropout, eps=60, mu=0:
# Sample: 0, Running Accuracy: 0.055
# Accuracy over 10000 samples: 0.063
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
# Evaluate MNIST Dropout, eps=90, mu=0:
# Sample: 0, Running Accuracy: 0.023
# Accuracy over 10000 samples: 0.021
# Skip Dropout at mu=0.1
# Skip Dropout at mu=0.2
# Skip Dropout at mu=0.3
# Skip Dropout at mu=0.4
# Skip Dropout at mu=0.5
#
# Evaluate MNIST RFN, eps=0, mu=0:
# Sample: 0, Running Accuracy: 0.992
# Accuracy over 10000 samples: 0.982
# Evaluate MNIST RFN, eps=0, mu=0.1:
# Sample: 0, Running Accuracy: 0.984
# Accuracy over 10000 samples: 0.981
# Evaluate MNIST RFN, eps=0, mu=0.2:
# Sample: 0, Running Accuracy: 0.992
# Accuracy over 10000 samples: 0.981
# Evaluate MNIST RFN, eps=0, mu=0.3:
# Sample: 0, Running Accuracy: 1.000
# Accuracy over 10000 samples: 0.978
# Evaluate MNIST RFN, eps=0, mu=0.4:
# Sample: 0, Running Accuracy: 0.984
# Accuracy over 10000 samples: 0.979
# Evaluate MNIST RFN, eps=0, mu=0.5:
# Sample: 0, Running Accuracy: 0.992
# Accuracy over 10000 samples: 0.973
# Evaluate MNIST RFN, eps=40, mu=0:
# Sample: 0, Running Accuracy: 0.094
# Accuracy over 10000 samples: 0.195
# Evaluate MNIST RFN, eps=40, mu=0.1:
# Sample: 0, Running Accuracy: 0.203
# Accuracy over 10000 samples: 0.356
# Evaluate MNIST RFN, eps=40, mu=0.2:
# Sample: 0, Running Accuracy: 0.328
# Accuracy over 10000 samples: 0.428
# Evaluate MNIST RFN, eps=40, mu=0.3:
# Sample: 0, Running Accuracy: 0.430
# Accuracy over 10000 samples: 0.517
# Evaluate MNIST RFN, eps=40, mu=0.4:
# Sample: 0, Running Accuracy: 0.523
# Accuracy over 10000 samples: 0.595
# Evaluate MNIST RFN, eps=40, mu=0.5:
# Sample: 0, Running Accuracy: 0.578
# Accuracy over 10000 samples: 0.680
# Evaluate MNIST RFN, eps=60, mu=0:
# Sample: 0, Running Accuracy: 0.047
# Accuracy over 10000 samples: 0.076
# Evaluate MNIST RFN, eps=60, mu=0.1:
# Sample: 0, Running Accuracy: 0.109
# Accuracy over 10000 samples: 0.176
# Evaluate MNIST RFN, eps=60, mu=0.2:
# Sample: 0, Running Accuracy: 0.211
# Accuracy over 10000 samples: 0.259
# Evaluate MNIST RFN, eps=60, mu=0.3:
# Sample: 0, Running Accuracy: 0.211
# Accuracy over 10000 samples: 0.318
# Evaluate MNIST RFN, eps=60, mu=0.4:
# Sample: 0, Running Accuracy: 0.281
# Accuracy over 10000 samples: 0.387
# Evaluate MNIST RFN, eps=60, mu=0.5:
# Sample: 0, Running Accuracy: 0.320
# Accuracy over 10000 samples: 0.435
# Evaluate MNIST RFN, eps=90, mu=0:
# Sample: 0, Running Accuracy: 0.016
# Accuracy over 10000 samples: 0.025
# Evaluate MNIST RFN, eps=90, mu=0.1:
# Sample: 0, Running Accuracy: 0.039
# Accuracy over 10000 samples: 0.070
# Evaluate MNIST RFN, eps=90, mu=0.2:
# Sample: 0, Running Accuracy: 0.078
# Accuracy over 10000 samples: 0.131
# Evaluate MNIST RFN, eps=90, mu=0.3:
# Sample: 0, Running Accuracy: 0.109
# Accuracy over 10000 samples: 0.172
# Evaluate MNIST RFN, eps=90, mu=0.4:
# Sample: 0, Running Accuracy: 0.203
# Accuracy over 10000 samples: 0.232
# Evaluate MNIST RFN, eps=90, mu=0.5:
# Sample: 0, Running Accuracy: 0.195
# Accuracy over 10000 samples: 0.250

# %%
import pickle
with open('./models/fulltrain25_mnist_analysis.pkl', 'wb') as f:
    pickle.dump(analysis, f)

with open('./models/fulltrain25_mnist_analysis.pkl', 'rb') as f:
    analysis = pickle.load(f)

# %%
print('MNIST FullTrain/Test vs FGSM')
print('\t\tFSGM Epsilons:')
print(f'MU  Model\t{0:<5}\t{40:<5}\t{60:<5}\t{90:<5}')
for model_name in models.keys():
    for mu in rfn_mu_vals:
        if model_name != 'RFN' and mu != 0:
            #print(f'Skip {model_name} at mu={mu}')
            continue
        print(f'{mu:<4}{model_name:<10}\t', end='')
        for eps in epsilons:
            print(f'{analysis[model_name][mu][eps]:.4}\t', end='')
        print()
# Out:
# MNIST FullTrain/Test vs FGSM
# 		FSGM Epsilons:
# MU  Model	0    	40   	60   	90
# 0   Standard  	0.9817	0.1678	0.0559	0.0227
# 0   Dropout   	0.9821	0.1789	0.063	0.0208
# 0   RFN       	0.9823	0.1949	0.0757	0.0252
# 0.1 RFN       	0.981	0.3557	0.1756	0.0695
# 0.2 RFN       	0.9805	0.428	0.2586	0.1306
# 0.3 RFN       	0.978	0.5169	0.3176	0.1724
# 0.4 RFN       	0.9785	0.5947	0.3874	0.2324
# 0.5 RFN       	0.9731	0.6796	0.4348	0.2499
